# %%
import pandas as pd 
import seaborn as sb 
import matplotlib as plt
import numpy as np 
from sklearn.preprocessing import StandardScaler 

df = pd.read_csv("/Users/apple/Downloads/10-ticker-data.csv")
num_df = df.select_dtypes(include='number')

scaler = StandardScaler()
standardised_data = scaler.fit_transform(num_df)

#make new df with the standardised data and the cols are the numeric ones only 
std_df = pd.DataFrame(standardised_data, columns=num_df.columns)  

corr_matrix = std_df.corr()

# Plot correlation heatmap
plt.figure(figsize=(8, 6))
sb.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap (Standardized Data)')
plt.show()

# %%
#data = df.select_dtypes(include=['number'])

########## without standardising ########

corr_matrix = num_df.corr()
plt.figure(figsize=(8,6))
sb.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0 , square=True, linewidths=0.5, cbar_kws={"shrink":.8})
plt.title('corr heatmap')
plt.tight_layout()
plt.show()
