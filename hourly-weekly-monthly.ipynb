# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# --- 1. Ticker List (Representative Tech Tickers) ---
tech_tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'META', 'TSM', 'AVGO', 'ORCL', 'CSCO', 'INTC', 'QCOM', 'AMD', 'CRM', 'ADBE']
# Let's limit to 10 for quicker processing in this example, you can use the full list
tech_tickers = tech_tickers[:10]

print(f"Selected Tech Tickers: {tech_tickers}")
print("\nIMPORTANT: Using 'Close' prices. These are NOT adjusted for dividends or stock splits.")
print("For analyses sensitive to total return or long-term price continuity, 'Adj Close' is usually preferred.\n")

# --- 2. Data Acquisition ---
# Download data for the last 5-10 years to have enough for yearly trends
try:
    data = yf.download(tech_tickers, start="2014-01-01", end="2024-01-01")
    # *** CHANGED HERE: Using 'Close' instead of 'Adj Close' ***
    close_prices = data['Close'].dropna(how='all') # Drop rows where all tickers are NaN
    # Forward fill to handle missing values for individual stocks
    # then backfill for any leading NaNs if a stock IPO'd later
    close_prices = close_prices.ffill().bfill()
    print("\nDownloaded Close Prices (head):")
    print(close_prices.head())
    if close_prices.isnull().sum().any():
        print("\nWarning: Remaining NaNs after ffill/bfill:")
        print(close_prices.isnull().sum()[close_prices.isnull().sum() > 0])
        close_prices = close_prices.dropna(axis=1, how='any') # Drop any columns that still have NaNs
        print(f"Tickers after dropping columns with NaNs: {close_prices.columns.tolist()}")

except Exception as e:
    print(f"Error downloading data: {e}")
    exit()

if close_prices.empty:
    print("No data to process. Exiting.")
    exit()

# --- 3. Resampling ---
resample_periods = {
    'Daily': 'D',
    'Weekly': 'W-FRI', # End of week on Friday
    'Monthly': 'M',    # End of month
    'Yearly': 'A'     # End of year (or 'Y')
}

resampled_prices = {}
for name, period_code in resample_periods.items():
    if name == 'Daily':
        # *** CHANGED HERE: Using close_prices ***
        resampled_prices[name] = close_prices
    else:
        # *** CHANGED HERE: Using close_prices ***
        resampled_prices[name] = close_prices.resample(period_code).last()

# --- 4. Common Ground / Normalization / Standardization ---

# Method A: Percentage Returns (Primary for "common ground" and statistical comparison)
returns_data = {}
for name, prices_df in resampled_prices.items():
    returns = prices_df.pct_change().dropna()
    returns_data[name] = returns
    print(f"\n{name} Returns (head):")
    print(returns.head())

# Method B: Re-indexing Prices to a Common Start (e.g., 100) for Visual Comparison
normalized_prices_to_100 = {}
for name, prices_df in resampled_prices.items():
    if not prices_df.empty and not prices_df.iloc[0].isnull().all():
         normalized_prices_to_100[name] = (prices_df / prices_df.iloc[0] * 100).dropna(how='all')
    else:
        print(f"Skipping normalization to 100 for {name} due to empty or all-NaN first row.")
        normalized_prices_to_100[name] = pd.DataFrame()

# Method C: Z-score Standardization (on returns, as prices are non-stationary)
standardized_returns_data = {}
scaler = StandardScaler()
for name, returns_df in returns_data.items():
    if not returns_df.empty:
        standardized_returns = pd.DataFrame(scaler.fit_transform(returns_df),
                                            index=returns_df.index,
                                            columns=returns_df.columns)
        standardized_returns_data[name] = standardized_returns
    else:
        standardized_returns_data[name] = pd.DataFrame()


# --- 5. Identifying Common Patterns ---

# Visual Inspection: Plotting normalized prices (re-indexed to 100)
print("\n--- Visualizing Normalized Price Paths (Indexed to 100) ---")
for name, df in normalized_prices_to_100.items():
    if not df.empty:
        plt.figure(figsize=(14, 7))
        for ticker in df.columns:
            plt.plot(df.index, df[ticker], label=ticker, alpha=0.7)
        plt.title(f'Normalized Price Paths (Indexed to 100) - {name} Frequency (Using Close Prices)')
        plt.xlabel('Date')
        plt.ylabel('Normalized Price (Start = 100)')
        plt.legend(loc='upper left', bbox_to_anchor=(1,1))
        plt.grid(True)
        plt.tight_layout()
        plt.show()
    else:
        print(f"No data to plot for normalized prices at {name} frequency.")

# Visual Inspection: Plotting returns
print("\n--- Visualizing Returns ---")
for name, df in returns_data.items():
    if not df.empty:
        plt.figure(figsize=(14, 7))
        for ticker in df.columns:
            plt.plot(df.index, df[ticker], label=ticker, alpha=0.7)
        if len(df.columns) > 1:
            sector_average_return = df.mean(axis=1)
            plt.plot(sector_average_return.index, sector_average_return, label='Sector Average', color='black', linewidth=2, linestyle='--')

        plt.title(f'Returns - {name} Frequency (Calculated from Close Prices)')
        plt.xlabel('Date')
        plt.ylabel('Percentage Return')
        plt.legend(loc='upper left', bbox_to_anchor=(1,1))
        plt.grid(True)
        plt.tight_layout()
        plt.show()
    else:
        print(f"No data to plot for returns at {name} frequency.")


# Correlation Analysis (on returns)
print("\n--- Correlation Analysis of Returns ---")
correlation_matrices = {}
for name, returns_df in returns_data.items():
    if not returns_df.empty and len(returns_df.columns) > 1:
        corr_matrix = returns_df.corr()
        correlation_matrices[name] = corr_matrix
        print(f"\nCorrelation Matrix - {name} Returns (from Close Prices):")
        print(corr_matrix)

        plt.figure(figsize=(10, 8))
        sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
        plt.title(f'Correlation Matrix of {name} Returns (from Close Prices)')
        plt.tight_layout()
        plt.show()
    elif returns_df.empty:
         print(f"Skipping correlation for {name} returns as DataFrame is empty.")
    else:
        print(f"Skipping correlation for {name} returns as there's only one ticker or no data.")


# --- 6. If Pattern is Common Irrespective of Frequency ---
print("\n--- Analyzing Patterns Across Frequencies (Using Close Prices) ---")
print("Observations from visual plots and correlation matrices:")
print("1. Daily returns are typically more 'noisy' (volatile) than weekly, monthly, or yearly returns.")
print("2. Lower frequencies (Weekly, Monthly, Yearly) tend to smooth out short-term fluctuations, potentially revealing broader, more synchronized trends among tech stocks.")
print("3. Correlation strengths: Compare the average correlation values or the general pattern in heatmaps across frequencies.")
print("   - Note: Unadjusted 'Close' prices can introduce artificial jumps due to stock splits, which might affect correlation calculations, especially if splits occur at different times for different stocks.")

for name, corr_matrix in correlation_matrices.items():
    if not corr_matrix.empty:
        num_tickers = corr_matrix.shape[0]
        if num_tickers > 1:
            avg_corr = (corr_matrix.values.sum() - num_tickers) / (num_tickers * (num_tickers - 1))
            print(f"Average off-diagonal correlation for {name} returns: {avg_corr:.3f}")
        else:
            print(f"Cannot calculate average off-diagonal correlation for {name} returns (single ticker).")

# --- 7. If Pattern is Not Common, Can We Use Some Transformation? ---
print("\n--- Transformations to Potentially Reveal Commonality (Using Close Prices) ---")
print("The primary transformations we've already used are:")
print("  a) Resampling (Aggregating to Lower Frequencies)")
print("  b) Percentage Change (Returns)")
print("  c) Log Returns (Alternative to Pct_Change):")

if 'Daily' in resampled_prices and not resampled_prices['Daily'].empty:
    # *** Using resampled_prices which is now based on 'Close' prices ***
    daily_log_returns = np.log(resampled_prices['Daily'] / resampled_prices['Daily'].shift(1)).dropna()
    print("\nDaily Log Returns (from Close Prices - head):")
    print(daily_log_returns.head())

    if not daily_log_returns.empty and len(daily_log_returns.columns) > 1:
        daily_log_corr = daily_log_returns.corr()
        print("\nCorrelation Matrix - Daily Log Returns (from Close Prices):")
        print(daily_log_corr)
        plt.figure(figsize=(10, 8))
        sns.heatmap(daily_log_corr, annot=True, cmap='coolwarm', fmt=".2f")
        plt.title('Correlation Matrix of Daily Log Returns (from Close Prices)')
        plt.tight_layout()
        plt.show()

        num_tickers_log = daily_log_corr.shape[0]
        if num_tickers_log > 1:
            avg_log_corr = (daily_log_corr.values.sum() - num_tickers_log) / (num_tickers_log * (num_tickers_log - 1))
            print(f"Average off-diagonal correlation for Daily Log returns: {avg_log_corr:.3f}")
            if 'Daily' in correlation_matrices and not correlation_matrices['Daily'].empty:
                num_tickers_simple = correlation_matrices['Daily'].shape[0]
                if num_tickers_simple > 1:
                     avg_simple_corr = (correlation_matrices['Daily'].values.sum() - num_tickers_simple) / (num_tickers_simple * (num_tickers_simple - 1))
                     print(f"Average off-diagonal correlation for Daily Simple returns: {avg_simple_corr:.3f}")
    else:
        print("Could not compute or display correlation for daily log returns.")
else:
    print("Daily price data not available for log return calculation.")

print("\nFurther transformation ideas if patterns are still elusive:")
print("  d) Detrending")
print("  e) Volatility Normalization")
print("  f) Advanced Methods: PCA, DTW")

print("\n--- Summary of Analysis (Using Close Prices) ---")
print("1. Common Ground for Comparison:")
print("   - Percentage returns (from Close prices).")
print("   - Normalizing Close prices to a common starting point (e.g., 100).")
print("   - Z-score standardization of returns (from Close prices).")
print("   - BE AWARE: Stock splits in 'Close' prices can create artificial jumps, affecting these comparisons.")

print("\n2. Common Patterns Irrespective of Frequency:")
print("   - Similar observations as with 'Adj Close' are expected regarding general co-movement, but specific magnitudes of correlations or visual patterns might differ due to the lack of adjustment for splits/dividends.")

print("\n3. Transformations for Commonality:")
print("   - Resampling and Log returns remain key transformations.")
print("   - The impact of using 'Close' vs 'Adj Close' is most pronounced in the raw price series and any direct calculations from it (like pct_change).")

print("\nFinal Thoughts:")
print("  - Analysis proceeds similarly, but interpret results cautiously, knowing that 'Close' prices do not account for splits or dividends, which can introduce non-market-driven price changes.")
# Out:
# Selected Tech Tickers: ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'META', 'TSM', 'AVGO', 'ORCL', 'CSCO']
#
# IMPORTANT: Using 'Close' prices. These are NOT adjusted for dividends or stock splits.
# For analyses sensitive to total return or long-term price continuity, 'Adj Close' is usually preferred.
#
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  10 of 10 completed
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_7067/3138112108.py:57: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled_prices[name] = close_prices.resample(period_code).last()
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_7067/3138112108.py:57: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   resampled_prices[name] = close_prices.resample(period_code).last()
# Downloaded Close Prices (head):
# Ticker           AAPL       AMZN      AVGO       CSCO      GOOGL       META  \
# Date
# 2014-01-02  17.192825  19.898500  3.929532  15.499214  27.689791  54.411491
# 2014-01-03  16.815168  19.822001  3.944459  15.485120  27.487797  54.262318
# 2014-01-06  16.906858  19.681499  3.917589  15.506259  27.794268  56.887913
# 2014-01-07  16.785952  19.901501  3.954907  15.717612  28.330095  57.603981
# 2014-01-08  16.892248  20.096001  4.013869  15.703525  28.389051  57.912289
#
# Ticker           MSFT      NVDA       ORCL        TSM
# Date
# 2014-01-02  30.939617  0.373906  31.815874  12.640018
# 2014-01-03  30.731468  0.369427  31.731539  12.492613
# 2014-01-06  30.082043  0.374377  31.605011  12.455760
# 2014-01-07  30.315144  0.380507  31.925526  12.463131
# 2014-01-08  29.773960  0.385694  31.815878  12.595798
#
# Daily Returns (head):
# Ticker          AAPL      AMZN      AVGO      CSCO     GOOGL      META  \
# Date
# 2014-01-03 -0.021966 -0.003845  0.003799 -0.000909 -0.007295 -0.002742
# 2014-01-06  0.005453 -0.007088 -0.006812  0.001365  0.011149  0.048387
# 2014-01-07 -0.007151  0.011178  0.009526  0.013630  0.019278  0.012587
# 2014-01-08  0.006332  0.009773  0.014909 -0.000896  0.002081  0.005352
# 2014-01-09 -0.012770 -0.002264 -0.010227 -0.008973 -0.009630 -0.017345
#
# Ticker          MSFT      NVDA      ORCL       TSM
# Date
# 2014-01-03 -0.006728 -0.011980 -0.002651 -0.011662
# 2014-01-06 -0.021132  0.013402 -0.003987 -0.002950
# 2014-01-07  0.007749  0.016373  0.010141  0.000592
# 2014-01-08 -0.017852  0.013631 -0.003434  0.010645
# 2014-01-09 -0.006431 -0.037286 -0.001856 -0.019310
#
# Weekly Returns (head):
# Ticker          AAPL      AMZN      AVGO      CSCO     GOOGL      META  \
# Date
# 2014-01-10 -0.014862  0.003077  0.008514  0.010919  0.022787  0.061950
# 2014-01-17  0.014504  0.004904  0.053284  0.023402  0.018006 -0.028305
# 2014-01-24  0.009988 -0.030054 -0.029391 -0.023746 -0.023207 -0.032860
# 2014-01-31 -0.083268 -0.074587  0.002753 -0.013063  0.050844  0.149128
# 2014-02-07  0.044328  0.006663  0.035322  0.034687 -0.002989  0.027969
#
# Ticker          MSFT      NVDA      ORCL       TSM
# Date
# 2014-01-10 -0.023571  0.003829  0.013025 -0.002950
# 2014-01-17  0.009434  0.016529  0.002624  0.051479
# 2014-01-24  0.011820 -0.026892 -0.028788 -0.011255
# 2014-01-31  0.027982  0.008997 -0.005659 -0.036995
# 2014-02-07 -0.033827  0.010828  0.007859  0.014185
#
# Monthly Returns (head):
# Ticker          AAPL      AMZN      AVGO      CSCO     GOOGL      META  \
# Date
# 2014-02-28  0.057511  0.009507  0.129209 -0.005021  0.029366  0.094135
# 2014-03-31  0.019953 -0.071058  0.048386  0.028440 -0.083198 -0.120070
# 2014-04-30  0.099396 -0.095847 -0.014128  0.039586 -0.041112 -0.007636
# 2014-05-31  0.078709  0.027685  0.112913  0.065340  0.068744  0.058883
# 2014-06-30  0.027662  0.039130  0.024000  0.009342  0.022776  0.063033
#
# Ticker          MSFT      NVDA      ORCL       TSM
# Date
# 2014-02-28  0.020013  0.175987  0.059892  0.067967
# 2014-03-31  0.069956 -0.025572  0.046024  0.107914
# 2014-04-30 -0.014394  0.031267  0.002246  0.003996
# 2014-05-31  0.020515  0.033433  0.027887  0.022885
# 2014-06-30  0.018564 -0.024211 -0.035459  0.040370
#
# Yearly Returns (head):
# Ticker          AAPL      AMZN      AVGO      CSCO     GOOGL      META  \
# Date
# 2015-12-31 -0.030137  1.177831  0.460370  0.006196  0.466118  0.341451
# 2016-12-31  0.124804  0.109456  0.236456  0.151337  0.018560  0.099274
# 2017-12-31  0.484643  0.559564  0.481861  0.312682  0.329295  0.533768
# 2018-12-31 -0.053902  0.284317  0.036220  0.165716 -0.008012 -0.257112
# 2019-12-31  0.889579  0.230277  0.290516  0.138126  0.281762  0.565718
#
# Ticker          MSFT      NVDA      ORCL       TSM
# Date
# 2015-12-31  0.226919  0.671155 -0.176310  0.048846
# 2016-12-31  0.150777  2.269603  0.068866  0.311169
# 2017-12-31  0.407306  0.819878  0.249369  0.424066
# 2018-12-31  0.207953 -0.308152 -0.029696 -0.035058
# 2019-12-31  0.575581  0.769430  0.193433  0.648419
#
# --- Visualizing Normalized Price Paths (Indexed to 100) ---
# --- Visualizing Returns ---
# --- Correlation Analysis of Returns ---
#
# Correlation Matrix - Daily Returns (from Close Prices):
# Ticker      AAPL      AMZN      AVGO      CSCO     GOOGL      META      MSFT  \
# Ticker
# AAPL    1.000000  0.541826  0.577609  0.536555  0.602062  0.528209  0.671104
# AMZN    0.541826  1.000000  0.440979  0.408540  0.641625  0.581573  0.620936
# AVGO    0.577609  0.440979  1.000000  0.509099  0.502715  0.449179  0.564567
# CSCO    0.536555  0.408540  0.509099  1.000000  0.495815  0.378543  0.578609
# GOOGL   0.602062  0.641625  0.502715  0.495815  1.000000  0.648576  0.711854
# META    0.528209  0.581573  0.449179  0.378543  0.648576  1.000000  0.564764
# MSFT    0.671104  0.620936  0.564567  0.578609  0.711854  0.564764  1.000000
# NVDA    0.552799  0.503403  0.579509  0.452353  0.546839  0.481269  0.606146
# ORCL    0.472921  0.369818  0.430262  0.530806  0.452085  0.364233  0.552639
# TSM     0.523154  0.422474  0.567870  0.426869  0.494483  0.398925  0.514974
#
# Ticker      NVDA      ORCL       TSM
# Ticker
# AAPL    0.552799  0.472921  0.523154
# AMZN    0.503403  0.369818  0.422474
# AVGO    0.579509  0.430262  0.567870
# CSCO    0.452353  0.530806  0.426869
# GOOGL   0.546839  0.452085  0.494483
# META    0.481269  0.364233  0.398925
# MSFT    0.606146  0.552639  0.514974
# NVDA    1.000000  0.404799  0.580126
# ORCL    0.404799  1.000000  0.396882
# TSM     0.580126  0.396882  1.000000
# Correlation Matrix - Weekly Returns (from Close Prices):
# Ticker      AAPL      AMZN      AVGO      CSCO     GOOGL      META      MSFT  \
# Ticker
# AAPL    1.000000  0.462391  0.515443  0.440267  0.530041  0.413057  0.597003
# AMZN    0.462391  1.000000  0.348569  0.359990  0.588893  0.443357  0.572891
# AVGO    0.515443  0.348569  1.000000  0.460651  0.401635  0.341613  0.491836
# CSCO    0.440267  0.359990  0.460651  1.000000  0.414816  0.261948  0.503360
# GOOGL   0.530041  0.588893  0.401635  0.414816  1.000000  0.574484  0.658181
# META    0.413057  0.443357  0.341613  0.261948  0.574484  1.000000  0.527323
# MSFT    0.597003  0.572891  0.491836  0.503360  0.658181  0.527323  1.000000
# NVDA    0.507988  0.498039  0.550096  0.396174  0.473308  0.411542  0.580990
# ORCL    0.424829  0.344087  0.356226  0.501486  0.416075  0.322336  0.512129
# TSM     0.469698  0.402478  0.501898  0.368997  0.448588  0.345265  0.434454
#
# Ticker      NVDA      ORCL       TSM
# Ticker
# AAPL    0.507988  0.424829  0.469698
# AMZN    0.498039  0.344087  0.402478
# AVGO    0.550096  0.356226  0.501898
# CSCO    0.396174  0.501486  0.368997
# GOOGL   0.473308  0.416075  0.448588
# META    0.411542  0.322336  0.345265
# MSFT    0.580990  0.512129  0.434454
# NVDA    1.000000  0.386668  0.528952
# ORCL    0.386668  1.000000  0.347856
# TSM     0.528952  0.347856  1.000000
# Correlation Matrix - Monthly Returns (from Close Prices):
# Ticker      AAPL      AMZN      AVGO      CSCO     GOOGL      META      MSFT  \
# Ticker
# AAPL    1.000000  0.539143  0.460663  0.444761  0.473888  0.402762  0.587273
# AMZN    0.539143  1.000000  0.324182  0.389350  0.647144  0.461384  0.598145
# AVGO    0.460663  0.324182  1.000000  0.422734  0.371500  0.352339  0.386954
# CSCO    0.444761  0.389350  0.422734  1.000000  0.389509  0.247082  0.431504
# GOOGL   0.473888  0.647144  0.371500  0.389509  1.000000  0.526697  0.633120
# META    0.402762  0.461384  0.352339  0.247082  0.526697  1.000000  0.444122
# MSFT    0.587273  0.598145  0.386954  0.431504  0.633120  0.444122  1.000000
# NVDA    0.571251  0.538209  0.481584  0.304497  0.517824  0.393856  0.564799
# ORCL    0.499071  0.387753  0.425908  0.496671  0.397712  0.242855  0.527868
# TSM     0.492170  0.443235  0.453692  0.304393  0.448624  0.428204  0.478381
#
# Ticker      NVDA      ORCL       TSM
# Ticker
# AAPL    0.571251  0.499071  0.492170
# AMZN    0.538209  0.387753  0.443235
# AVGO    0.481584  0.425908  0.453692
# CSCO    0.304497  0.496671  0.304393
# GOOGL   0.517824  0.397712  0.448624
# META    0.393856  0.242855  0.428204
# MSFT    0.564799  0.527868  0.478381
# NVDA    1.000000  0.474408  0.513145
# ORCL    0.474408  1.000000  0.361955
# TSM     0.513145  0.361955  1.000000
# Correlation Matrix - Yearly Returns (from Close Prices):
# Ticker      AAPL      AMZN      AVGO      CSCO     GOOGL      META      MSFT  \
# Ticker
# AAPL    1.000000  0.326685  0.508484  0.295829  0.541978  0.559028  0.820757
# AMZN    0.326685  1.000000  0.640817  0.049657  0.649687  0.600391  0.514610
# AVGO    0.508484  0.640817  1.000000  0.375861  0.875170  0.932460  0.768172
# CSCO    0.295829  0.049657  0.375861  1.000000  0.600896  0.237679  0.632392
# GOOGL   0.541978  0.649687  0.875170  0.600896  1.000000  0.724066  0.864140
# META    0.559028  0.600391  0.932460  0.237679  0.724066  1.000000  0.747504
# MSFT    0.820757  0.514610  0.768172  0.632392  0.864140  0.747504  1.000000
# NVDA    0.451799  0.362287  0.751999  0.327170  0.575628  0.723585  0.564884
# ORCL    0.729035 -0.015115  0.615905  0.578611  0.568373  0.551258  0.729682
# TSM     0.931951  0.479786  0.490094  0.185024  0.476992  0.531897  0.729945
#
# Ticker      NVDA      ORCL       TSM
# Ticker
# AAPL    0.451799  0.729035  0.931951
# AMZN    0.362287 -0.015115  0.479786
# AVGO    0.751999  0.615905  0.490094
# CSCO    0.327170  0.578611  0.185024
# GOOGL   0.575628  0.568373  0.476992
# META    0.723585  0.551258  0.531897
# MSFT    0.564884  0.729682  0.729945
# NVDA    1.000000  0.544606  0.554389
# ORCL    0.544606  1.000000  0.584603
# TSM     0.554389  0.584603  1.000000
# --- Analyzing Patterns Across Frequencies (Using Close Prices) ---
# Observations from visual plots and correlation matrices:
# 1. Daily returns are typically more 'noisy' (volatile) than weekly, monthly, or yearly returns.
# 2. Lower frequencies (Weekly, Monthly, Yearly) tend to smooth out short-term fluctuations, potentially revealing broader, more synchronized trends among tech stocks.
# 3. Correlation strengths: Compare the average correlation values or the general pattern in heatmaps across frequencies.
#    - Note: Unadjusted 'Close' prices can introduce artificial jumps due to stock splits, which might affect correlation calculations, especially if splits occur at different times for different stocks.
# Average off-diagonal correlation for Daily returns: 0.515
# Average off-diagonal correlation for Weekly returns: 0.454
# Average off-diagonal correlation for Monthly returns: 0.451
# Average off-diagonal correlation for Yearly returns: 0.562
#
# --- Transformations to Potentially Reveal Commonality (Using Close Prices) ---
# The primary transformations we've already used are:
#   a) Resampling (Aggregating to Lower Frequencies)
#   b) Percentage Change (Returns)
#   c) Log Returns (Alternative to Pct_Change):
#
# Daily Log Returns (from Close Prices - head):
# Ticker          AAPL      AMZN      AVGO      CSCO     GOOGL      META  \
# Date
# 2014-01-03 -0.022211 -0.003852  0.003791 -0.000910 -0.007322 -0.002745
# 2014-01-06  0.005438 -0.007113 -0.006835  0.001364  0.011088  0.047253
# 2014-01-07 -0.007177  0.011116  0.009481  0.013538  0.019095  0.012509
# 2014-01-08  0.006313  0.009726  0.014798 -0.000897  0.002079  0.005338
# 2014-01-09 -0.012852 -0.002267 -0.010280 -0.009013 -0.009677 -0.017497
#
# Ticker          MSFT      NVDA      ORCL       TSM
# Date
# 2014-01-03 -0.006750 -0.012052 -0.002654 -0.011730
# 2014-01-06 -0.021359  0.013313 -0.003995 -0.002954
# 2014-01-07  0.007719  0.016240  0.010090  0.000592
# 2014-01-08 -0.018013  0.013539 -0.003440  0.010589
# 2014-01-09 -0.006452 -0.037999 -0.001857 -0.019499
#
# Correlation Matrix - Daily Log Returns (from Close Prices):
# Ticker      AAPL      AMZN      AVGO      CSCO     GOOGL      META      MSFT  \
# Ticker
# AAPL    1.000000  0.543517  0.581947  0.535888  0.605586  0.524849  0.673201
# AMZN    0.543517  1.000000  0.444419  0.410105  0.644455  0.579940  0.620792
# AVGO    0.581947  0.444419  1.000000  0.509904  0.507645  0.449278  0.569886
# CSCO    0.535888  0.410105  0.509904  1.000000  0.496492  0.374655  0.577364
# GOOGL   0.605586  0.644455  0.507645  0.496492  1.000000  0.644109  0.715190
# META    0.524849  0.579940  0.449278  0.374655  0.644109  1.000000  0.562892
# MSFT    0.673201  0.620792  0.569886  0.577364  0.715190  0.562892  1.000000
# NVDA    0.560448  0.513316  0.587336  0.455049  0.556337  0.484549  0.614226
# ORCL    0.471955  0.372857  0.431040  0.526618  0.454195  0.361799  0.550809
# TSM     0.526935  0.425903  0.575039  0.427492  0.498943  0.399275  0.518638
#
# Ticker      NVDA      ORCL       TSM
# Ticker
# AAPL    0.560448  0.471955  0.526935
# AMZN    0.513316  0.372857  0.425903
# AVGO    0.587336  0.431040  0.575039
# CSCO    0.455049  0.526618  0.427492
# GOOGL   0.556337  0.454195  0.498943
# META    0.484549  0.361799  0.399275
# MSFT    0.614226  0.550809  0.518638
# NVDA    1.000000  0.407614  0.586052
# ORCL    0.407614  1.000000  0.397884
# TSM     0.586052  0.397884  1.000000
# Average off-diagonal correlation for Daily Log returns: 0.517
# Average off-diagonal correlation for Daily Simple returns: 0.515
#
# Further transformation ideas if patterns are still elusive:
#   d) Detrending
#   e) Volatility Normalization
#   f) Advanced Methods: PCA, DTW
#
# --- Summary of Analysis (Using Close Prices) ---
# 1. Common Ground for Comparison:
#    - Percentage returns (from Close prices).
#    - Normalizing Close prices to a common starting point (e.g., 100).
#    - Z-score standardization of returns (from Close prices).
#    - BE AWARE: Stock splits in 'Close' prices can create artificial jumps, affecting these comparisons.
#
# 2. Common Patterns Irrespective of Frequency:
#    - Similar observations as with 'Adj Close' are expected regarding general co-movement, but specific magnitudes of correlations or visual patterns might differ due to the lack of adjustment for splits/dividends.
#
# 3. Transformations for Commonality:
#    - Resampling and Log returns remain key transformations.
#    - The impact of using 'Close' vs 'Adj Close' is most pronounced in the raw price series and any direct calculations from it (like pct_change).
#
# Final Thoughts:
#   - Analysis proceeds similarly, but interpret results cautiously, knowing that 'Close' prices do not account for splits or dividends, which can introduce non-market-driven price changes.

# %%
########### HOURLY ############
# --- 1. Ticker List (Same as before) ---
tech_tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'META', 'TSM', 'AVGO', 'ORCL', 'CSCO'] # Using 10 for brevity
# tech_tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'META', 'TSM', 'AVGO', 'ORCL', 'CSCO', 'INTC', 'QCOM', 'AMD', 'CRM', 'ADBE']


print(f"Selected Tech Tickers: {tech_tickers}")

# --- 2. Define Time Period (Approx. 22 market days) ---
# yfinance intraday data is typically available for the last 60 days for 1h interval.
# We'll aim for roughly the last month of trading.
end_date = datetime.now()
# Go back a bit more than 22 business days to ensure we capture enough data after filtering
# (e.g., 45 calendar days should be safe to get ~30 business days)
start_date = end_date - timedelta(days=45)

print(f"Attempting to fetch data from {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}")

# --- 3. Download Hourly Data ---
all_hourly_data = {}
valid_tickers = []

for ticker in tech_tickers:
    try:
        # For '1h' interval, yfinance typically provides data for the last 730 days if period is not specified.
        # However, to be safe and specific, we use start/end. Max period for 1h is often 730d.
        # For very recent data, yfinance might have limitations on how far back 1h data goes.
        # Let's try to get a bit more than needed and then slice.
        # Max period for 1h interval is 730 days. For shorter periods like a month, start/end is fine.
        # yfinance often returns data for the last 60 *calendar* days for 1h interval if no explicit period is given.
        # Using start/end is more reliable for specific ranges.
        data = yf.download(ticker, start=start_date, end=end_date, interval="1h", progress=False)
        if not data.empty and 'Close' in data.columns:
            all_hourly_data[ticker] = data[['Close']]
            valid_tickers.append(ticker)
            print(f"Successfully downloaded hourly data for {ticker}")
        else:
            print(f"No hourly data found for {ticker} in the specified range.")
    except Exception as e:
        print(f"Could not download hourly data for {ticker}: {e}")

if not valid_tickers:
    print("No data downloaded for any ticker. Exiting.")
    exit()

tech_tickers = valid_tickers # Update ticker list to only those with data

# Combine into a single DataFrame
hourly_close_df = pd.concat(all_hourly_data, axis=1)
hourly_close_df.columns = hourly_close_df.columns.droplevel(1) # Remove 'Close' from multi-index
hourly_close_df = hourly_close_df.dropna(how='all') # Drop rows where all tickers are NaN

# Filter for typical US market hours (e.g., 9:30 AM to 4:00 PM ET)
# yfinance data is usually timezone-aware (often ET for US stocks)
# Let's assume the data is in ET. If not, tz_localize and tz_convert might be needed.
if hourly_close_df.index.tz is None:
    print("Warning: Timezone not set on index. Assuming ET. This might be incorrect.")
    hourly_close_df = hourly_close_df.tz_localize('America/New_York', ambiguous='NaT', nonexistent='NaT')
else:
    hourly_close_df = hourly_close_df.tz_convert('America/New_York')

hourly_close_df = hourly_close_df.between_time('09:30', '16:00') # Includes 9:30, 10:30 ... 15:30 (as Close of the hour bar)

# Ensure we have roughly 22 unique market days of data
unique_days = hourly_close_df.index.normalize().unique()
if len(unique_days) > 22:
    # Take the most recent 22 unique days
    start_of_22_days = unique_days[-22]
    hourly_close_df = hourly_close_df[hourly_close_df.index.normalize() >= start_of_22_days]
elif len(unique_days) < 5: # Arbitrary threshold for too little data
    print(f"Too few unique market days ({len(unique_days)}) with hourly data after filtering. Analysis might be unreliable.")
    if hourly_close_df.empty:
        print("DataFrame is empty after filtering. Exiting.")
        exit()

print(f"\nUsing data for {len(hourly_close_df.index.normalize().unique())} unique market days.")
print("Hourly Close Prices (head):")
print(hourly_close_df.head())

# --- 4. Normalize Data: Percentage Change from Market Open ---
# We need the opening price for each stock on each day.
# The first available price in our filtered data for each day can serve as a proxy for 'effective open'.
def calculate_pct_change_from_open(df):
    df_pct_change = df.copy()
    for day in df.index.normalize().unique():
        daily_data = df[df.index.normalize() == day]
        if not daily_data.empty:
            # Use the first valid price of the day as the open reference
            open_prices = daily_data.bfill().iloc[0] # Backfill to get first valid price if 9:30 is NaN
            for ticker in df.columns:
                if ticker in open_prices and pd.notna(open_prices[ticker]):
                    df_pct_change.loc[daily_data.index, ticker] = \
                        (daily_data[ticker] / open_prices[ticker] - 1) * 100
                else: # If no open price for this ticker on this day (should be rare after bfill)
                    df_pct_change.loc[daily_data.index, ticker] = np.nan
    return df_pct_change

normalized_hourly_df = calculate_pct_change_from_open(hourly_close_df)
normalized_hourly_df = normalized_hourly_df.dropna(how='all', axis=0) # Drop rows that became all NaN

if normalized_hourly_df.empty:
    print("Normalized DataFrame is empty. Cannot proceed with visualization. Check data or normalization logic.")
    exit()

print("\nNormalized Hourly Prices (% Change from Open - head):")
print(normalized_hourly_df.head())


# --- 5. Visualization ---

# Plot 1: Average Intraday Profile for All Tickers
# This shows the "common ground" or average hourly trend.
print("\nPlotting Average Intraday Profile for All Tickers...")
average_intraday_profile = normalized_hourly_df.groupby(normalized_hourly_df.index.time).mean()

plt.figure(figsize=(14, 7))
for ticker in average_intraday_profile.columns:
    plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')

plt.title(f'Average Intraday Profile (% Change from Open)\n(Averaged over last ~22 market days)')
plt.xlabel('Hour of Day (ET)')
plt.ylabel('% Change from Open')
plt.xticks(rotation=45)
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot 2: Daily Intraday "Spaghetti Plot" for a Few Selected Tickers
# This shows if the trend remains the same over every hour across different market days for individual stocks.
print("\nPlotting Daily Intraday Profiles for Selected Tickers...")
tickers_to_plot_daily = tech_tickers[:3] # Plot for the first 3 tickers

for ticker in tickers_to_plot_daily:
    if ticker not in normalized_hourly_df.columns:
        print(f"Skipping daily plot for {ticker} as it's not in the normalized data.")
        continue

    plt.figure(figsize=(14, 7))
    # Pivot data to have days as columns (or iterate through days)
    # For plotting, iterating through days is straightforward
    unique_days_in_data = normalized_hourly_df.index.normalize().unique()

    for day in unique_days_in_data:
        daily_ticker_data = normalized_hourly_df.loc[normalized_hourly_df.index.normalize() == day, ticker]
        if not daily_ticker_data.empty:
            plt.plot(daily_ticker_data.index.time.astype(str), daily_ticker_data.values, marker='.', linestyle='-', alpha=0.5, label=day.strftime('%Y-%m-%d') if day == unique_days_in_data[0] else "_nolegend_") # Only label one day for legend clarity

    plt.title(f'Daily Intraday Profiles for {ticker} (% Change from Open)')
    plt.xlabel('Hour of Day (ET)')
    plt.ylabel('% Change from Open')
    plt.xticks(rotation=45)
    # plt.legend(title="Day", loc='upper left', bbox_to_anchor=(1,1)) # Can be too cluttered
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Plot 3: Heatmap of Average Intraday Profiles
# This can also show commonality in shape.
print("\nPlotting Heatmap of Average Intraday Profiles...")
plt.figure(figsize=(10, 8))
sns.heatmap(average_intraday_profile.T, annot=True, cmap="RdYlGn", center=0, fmt=".2f") # Transpose for tickers on Y-axis
plt.title('Heatmap of Average Hourly % Change from Open')
plt.xlabel('Hour of Day (ET)')
plt.ylabel('Ticker')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

print("\nAnalysis Complete.")
print("Interpretation Notes:")
print("1. 'Average Intraday Profile': Look for similar shapes across tickers. Do they all tend to dip or rise at certain hours?")
print("2. 'Daily Intraday Profiles': For a single stock, see how consistent its hourly pattern is from one day to the next.")
print("   - High consistency = predictable intraday behavior.")
print("   - Low consistency = intraday behavior varies greatly day-to-day.")
print("3. 'Heatmap': Provides a compact view of the average profiles. Green might mean positive avg % change, Red negative.")
print("Common ground/trend: If many tickers show similar shapes in Plot 1 or similar color patterns in Plot 3 for specific hours, that indicates a common hourly trend.")
# Out:
# Selected Tech Tickers: ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'META', 'TSM', 'AVGO', 'ORCL', 'CSCO']
# Attempting to fetch data from 2025-05-10 to 2025-06-24
# YF.download() has changed argument auto_adjust default to True
# Successfully downloaded hourly data for AAPL
# Successfully downloaded hourly data for MSFT
# Successfully downloaded hourly data for GOOGL
# Successfully downloaded hourly data for AMZN
# Successfully downloaded hourly data for NVDA
# Successfully downloaded hourly data for META
# Successfully downloaded hourly data for TSM
# Successfully downloaded hourly data for AVGO
# Successfully downloaded hourly data for ORCL
# Successfully downloaded hourly data for CSCO
#
# Using data for 22 unique market days.
# Hourly Close Prices (head):
#                                  AAPL        MSFT       GOOGL        AMZN  \
# Ticker                           AAPL        MSFT       GOOGL        AMZN
# Datetime
# 2025-05-21 09:30:00-04:00  205.809998  455.945007  169.320007  201.678604
# 2025-05-21 10:30:00-04:00  206.580002  456.915009  172.641602  202.925003
# 2025-05-21 11:30:00-04:00  205.639999  456.920013  171.539993  203.070007
# 2025-05-21 12:30:00-04:00  202.100006  452.454987  169.130005  200.829895
# 2025-05-21 13:30:00-04:00  202.341507  453.725006  169.375000  201.520004
#
#                                  NVDA        META         TSM        AVGO  \
# Ticker                           NVDA        META         TSM        AVGO
# Datetime
# 2025-05-21 09:30:00-04:00  134.085007  640.945007  193.130005  231.785004
# 2025-05-21 10:30:00-04:00  135.875793  644.489990  194.710007  234.350006
# 2025-05-21 11:30:00-04:00  137.085007  642.148621  194.875000  236.154999
# 2025-05-21 12:30:00-04:00  133.214996  631.679993  191.449997  230.059998
# 2025-05-21 13:30:00-04:00  132.845001  636.070007  192.059998  230.975006
#
#                                  ORCL       CSCO
# Ticker                           ORCL       CSCO
# Datetime
# 2025-05-21 09:30:00-04:00  159.296204  63.503502
# 2025-05-21 10:30:00-04:00  160.500000  63.730000
# 2025-05-21 11:30:00-04:00  160.380005  63.794998
# 2025-05-21 12:30:00-04:00  158.020004  63.250000
# 2025-05-21 13:30:00-04:00  157.919998  63.347301
#
# Normalized Hourly Prices (% Change from Open - head):
#                                AAPL      MSFT     GOOGL      AMZN      NVDA  \
# Ticker                         AAPL      MSFT     GOOGL      AMZN      NVDA
# Datetime
# 2025-05-21 09:30:00-04:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2025-05-21 10:30:00-04:00  0.374134  0.212745  1.961726  0.618012  1.335561
# 2025-05-21 11:30:00-04:00 -0.082600  0.213843  1.311119  0.689911  2.237387
# 2025-05-21 12:30:00-04:00 -1.802629 -0.765448 -0.112215 -0.420823 -0.648850
# 2025-05-21 13:30:00-04:00 -1.685288 -0.486901  0.032479 -0.078640 -0.924791
#
#                                META       TSM      AVGO      ORCL      CSCO
# Ticker                         META       TSM      AVGO      ORCL      CSCO
# Datetime
# 2025-05-21 09:30:00-04:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2025-05-21 10:30:00-04:00  0.553087  0.818103  1.106630  0.755697  0.356670
# 2025-05-21 11:30:00-04:00  0.187787  0.903534  1.885366  0.680369  0.459024
# 2025-05-21 12:30:00-04:00 -1.445524 -0.869884 -0.744227 -0.801149 -0.399194
# 2025-05-21 13:30:00-04:00 -0.760596 -0.554035 -0.349461 -0.863929 -0.245971
#
# Plotting Average Intraday Profile for All Tickers...
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# /var/folders/s4/ltdhgr6d5nlgnqb60vkcr5700000gn/T/ipykernel_5145/1239268131.py:124: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(average_intraday_profile.index.astype(str), average_intraday_profile[ticker], label=ticker, marker='o', linestyle='-')
# Plotting Daily Intraday Profiles for Selected Tickers...
# Plotting Heatmap of Average Intraday Profiles...
# Analysis Complete.
# Interpretation Notes:
# 1. 'Average Intraday Profile': Look for similar shapes across tickers. Do they all tend to dip or rise at certain hours?
# 2. 'Daily Intraday Profiles': For a single stock, see how consistent its hourly pattern is from one day to the next.
#    - High consistency = predictable intraday behavior.
#    - Low consistency = intraday behavior varies greatly day-to-day.
# 3. 'Heatmap': Provides a compact view of the average profiles. Green might mean positive avg % change, Red negative.
# Common ground/trend: If many tickers show similar shapes in Plot 1 or similar color patterns in Plot 3 for specific hours, that indicates a common hourly trend.
