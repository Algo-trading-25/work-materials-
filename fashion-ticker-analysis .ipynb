# %%
tickers = [
    # Luxury & Designer
    "MC.PA",      # LVMH
    "RMS.PA",     # Hermès
    "KER.PA",     # Kering
    "1913.HK",    # Prada
    "MONC.MI",    # Moncler
    "BRBY.L",     # Burberry
    "BC.MI",      # Brunello Cucinelli
    "SFER.MI",    # Salvatore Ferragamo
    "TPR",        # Tapestry (Coach, Kate Spade)
    "CPRI",       # Capri Holdings (Versace, Michael Kors)
    "RL",         # Ralph Lauren
    "BOSS.DE",    # Hugo Boss
    "ZGN",        # Ermenegildo Zegna
    "PVH",        # PVH Corp. (Calvin Klein, Tommy Hilfiger)
    "EL",         # Estee Lauder (Tom Ford, Jo Malone)
    "UHR.SW",     # Swatch Group
    "MOV",        # Movado Group

    # Sportswear/Athleisure
    "NKE",        # Nike
    "ADS.DE",     # Adidas
    "PUM.DE",     # Puma
    "LULU",       # Lululemon
    "UAA",        # Under Armour
    "COLM",       # Columbia Sportswear
    "DECK",       # Deckers Outdoor (HOKA, UGG)
    "SKX",        # Skechers
    "ONON",       # On Holding
    "ASICS.T",    # Asics Corp (Japan)
    "2331.HK",    # Li Ning

    # Fast Fashion / Mass Market
    "ITX.MC",     # Inditex (Zara, Massimo Dutti)
    "HM-B.ST",    # H&M
    "9983.T",     # Fast Retailing (Uniqlo)
    "GPS",        # Gap Inc.
    "URBN",       # Urban Outfitters
    "ANF",        # Abercrombie & Fitch
    "AEO",        # American Eagle Outfitters
    "ATZ.TO",     # Aritzia
    "BOO.L",      # Boohoo Group
    "ASC.L",      # ASOS
    "ZAL.DE",     # Zalando

    # Premium/Bridge
    "SHOO",       # Steve Madden
    "GES",        # Guess?
    "GIII",       # G-III Apparel Group
    "OXM",        # Oxford Industries
    "HBI",        # Hanesbrands
    "LEVI",       # Levi Strauss & Co.
    "VFC",        # VF Corp (The North Face, Vans)
    "KTB",        # Kontoor Brands (Wrangler, Lee)

    # Department & Off-Price Retailers
    "TJX",        # TJX Companies (TJ Maxx, Marshalls)
    "ROST",       # Ross Stores
    "BURL",       # Burlington Stores
    "M",          # Macy's
    "JWN",        # Nordstrom
    "DDS",        # Dillard's
    "KSS",        # Kohl's

    # Footwear & Accessories
    "CROX",       # Crocs
    "BIRK",       # Birkenstock
    "BKE",        # Buckle
    "FL",         # Foot Locker

    # Other Notable Public Apparel Brands
    "JD.L",       # JD Sports Fashion
    "SFER.MI",    # Salvatore Ferragamo
    "PRDSY",      # Prada (US ADR)
    "HUGO.DE",    # Hugo Boss (alternate ticker)
    "ZGN.MI",     # Ermenegildo Zegna (Italy)
    "VSCO",       # Victoria's Secret
    "CRI",        # Carter's
    "WOLV",       # Wolverine World Wide
    "WOSG.L",     # Watches of Switzerland
    "URBN",       # Urban Outfitters
    "SMCP.PA",    # SMCP Group (Sandro, Maje)
    "VAN.DE",     # Van de Velde Lingerie
    "MOV",        # Movado Group
    "BIRD",       # Allbirds
    "TDUP",       # ThredUp
]

# %%
tickers_largecap_luxury = [
    "RMS.PA",       # Hermès
    "MC.PA",        # LVMH (Moët Hennessy Louis Vuitton)
    "LVMHF",        # LVMH (US ADR)
    "KER.PA",       # Kering
    "LULU",         # Lululemon Athletica
    "TPR",          # Tapestry
    "RL",           # Ralph Lauren
    "EL",           # Estée Lauder
    "MONC.MI",      # Moncler
    "1913.HK",      # Prada
    "BRBY.L",       # Burberry
    "RACE",         # Ferrari (luxury autos, fashion crossover)
    "CFR.SW",       # Richemont (Cartier, Van Cleef & Arpels)
    "CDI.PA",       # Christian Dior
    "PRTP.PA",      # Hermès (alternate Paris ticker)
    "ESSI.PA",      # EssilorLuxottica (luxury eyewear)
    "PUIG.MC",      # Puig (Carolina Herrera, Paco Rabanne, Jean Paul Gaultier)
    "CHOWTAIFOOK.HK", # Chow Tai Fook (jewelry, luxury)
    "TITAN.NS",     # Titan Company (jewelry, watches, India)
]

# %%
tickers_midcap_luxury = [
    "BRNC.MI",      # Brunello Cucinelli
    "SFER.MI",      # Salvatore Ferragamo
    "BOSS.DE",      # Hugo Boss
    "ZGN",          # Ermenegildo Zegna
    "PVH",          # PVH Corp (Calvin Klein, Tommy Hilfiger)
    "CPRI",         # Capri Holdings (Michael Kors, Versace, Jimmy Choo)
    "SWGAY",        # Swatch Group (US ADR)
    "UHR.SW",       # Swatch Group (Swiss)
    "BIRK",         # Birkenstock
    "WOSG.L",       # Watches of Switzerland
    "MOV",          # Movado Group
    "VAN.DE",       # Van de Velde (luxury lingerie)
    "SMCP.PA",      # SMCP Group (Sandro, Maje, Claudie Pierlot)
    "PRAN.MI",      # Prada (alternate Milan ticker)
]

# %%
tickers_smallcap_luxury = [
    "GIII",         # G-III Apparel Group (owns Karl Lagerfeld, DKNY)
    "OXM",          # Oxford Industries (Tommy Bahama, Lilly Pulitzer)
    "LEVI",         # Levi Strauss (premium denim, some luxury collabs)
    "VSCO",         # Victoria's Secret (premium/luxury lingerie)
    "CRAI.MI",      # Crai (Italian premium/luxury retail)
    "MOV",          # Movado Group (luxury watches)
    "SMCP.PA",      # SMCP Group (Sandro, Maje, Claudie Pierlot)
    "AWWG.MC",      # All We Wear Group (Pepe Jeans, Hackett London)
    "MARIMEKKO.HE", # Marimekko (premium/luxury design, Finland)
    "VAN.DE",       # Van de Velde (luxury lingerie)
    "TDUP",         # ThredUp (luxury resale, US)
]

# %%
import pandas as pd         
import seaborn as sns       
import matplotlib.pyplot as plt  
import numpy as np          
from sklearn.preprocessing import StandardScaler

import yfinance as yf


def download_ticker_data(ticker_list, period='22d'):   #22 days for now = monthly 
    """Download historical data for a list of tickers and return dictionary of DataFrames"""
    data = yf.download(
        ticker_list,
        period=period,
        interval='1d',
        group_by='ticker',
        progress=False
    )
    
    # Separate into individual DataFrames
    return {ticker: data[ticker] for ticker in ticker_list if ticker in data.columns.get_level_values(0)}

# Download data for each category
#calling function on each ticker lsit separately 
largecap_data = download_ticker_data(tickers_largecap_luxury)
midcap_data = download_ticker_data(tickers_midcap_luxury)
smallcap_data = download_ticker_data(tickers_smallcap_luxury)

# Example: Access data for Hermès
hermes_df = largecap_data["RMS.PA"]
print(hermes_df.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# 4 Failed downloads:
# ['ESSI.PA', 'PRTP.PA']: YFPricesMissingError('possibly delisted; no price data found  (period=22d)')
# ['PUIG.MC']: ValueError('Length mismatch: Expected axis has 2 elements, new values have 1 elements')
# ['CHOWTAIFOOK.HK']: HTTPError('HTTP Error 404: ')
#
# 3 Failed downloads:
# ['PRAN.MI']: HTTPError('HTTP Error 404: ')
# ['BRNC.MI']: YFPricesMissingError('possibly delisted; no price data found  (period=22d) (Yahoo error = "No data found, symbol may be delisted")')
# ['VAN.DE']: YFPricesMissingError('possibly delisted; no price data found  (period=22d)')
#
# 4 Failed downloads:
# ['AWWG.MC', 'CRAI.MI', 'MARIMEKKO.HE']: YFPricesMissingError('possibly delisted; no price data found  (period=22d) (Yahoo error = "No data found, symbol may be delisted")')
# ['VAN.DE']: YFPricesMissingError('possibly delisted; no price data found  (period=22d)')
# Price         Open    High     Low   Close   Volume
# ...

# %%
#corr within a category -> amongst tickers of same industry large-small-mid any one only 

# Combine 'Close' from all tickers in largecap_data
adj_close_largecap = pd.DataFrame({
    ticker: df['Close'] for ticker, df in largecap_data.items()
})

# Calculate correlation matrix
corr_matrix_largecap = adj_close_largecap.corr()

# Plot heatmap
plt.figure(figsize=(14, 12))
sns.heatmap(corr_matrix_largecap, annot=True, cmap='coolwarm')
plt.title('Large Cap Luxury Brands Correlation Heatmap')
plt.show()

# %%
#corr within a category -> amongst tickers of same industry large-small-mid any one only 

# Combine 'Close' from all tickers in largecap_data
close_smallcap = pd.DataFrame({
    ticker: df['Close'] for ticker, df in smallcap_data.items()
})

# Calculate correlation matrix
corr_matrix_smallcap = close_smallcap.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix_smallcap, annot=True, cmap='coolwarm')
plt.title('Small Cap Luxury Brands Correlation Heatmap')
plt.show()

# %%
#corr within a category -> amongst tickers of same industry large-small-mid any one only 

# Combine 'Close' from all tickers in largecap_data
close_midcap = pd.DataFrame({
    ticker: df['Close'] for ticker, df in midcap_data.items()
})

# Calculate correlation matrix
corr_matrix_midcap = close_midcap.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix_midcap, annot=True, cmap='coolwarm')
plt.title('Mid Cap Luxury Brands Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Aggregate each category into a single time series
def aggregate_category(data_dict):
    """Combine all tickers in a category into one average time series"""
    close_df = pd.DataFrame({
        ticker: df['Close'] 
        for ticker, df in data_dict.items()
    })
    return close_df.mean(axis=1)  # Daily average of all tickers

# Create aggregated time series for each category
largecap_agg = aggregate_category(largecap_data).rename('Largecap')
midcap_agg = aggregate_category(midcap_data).rename('Midcap')
smallcap_agg = aggregate_category(smallcap_data).rename('Smallcap')

# Combine into single DataFrame
combined_df = pd.concat([
    largecap_agg, 
    midcap_agg, 
    smallcap_agg
], axis=1)

# Calculate correlation between categories
corr_matrix = combined_df.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix, 
    annot=True, 
    cmap='coolwarm', 
    fmt=".2f",
    linewidths=0.5,
    vmin=-1, vmax=1,
    mask=np.triu(np.ones_like(corr_matrix, dtype=bool))  # Mask upper triangle
)
plt.title('Correlation Between Market Cap Categories', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
